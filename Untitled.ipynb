# %%
import numpy as np
import pandas as pd
import networkx as nx
import community as louvain_community
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %%
codes = pd.read_csv('data/codes.csv')
df = pd.read_csv('data/dij_joint_civ.csv')

# %%
codes.set_index('Code', inplace=True)

# %%
edge_list = []
for index, row in df.iterrows():
    edge_list.append((row['i'], row['j'], {'cost':0, 'weight':row['D_ij']}))
G = nx.Graph(edge_list)

# %%
plt.figure(figsize=(12, 8))
elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0]
pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=.2)

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")

plt.show()

# %%
greater_than_0_edge_list = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] > 3]
G_greater_than_0 = nx.Graph(greater_than_0_edge_list)

# %%
partition = louvain_community.best_partition(G_greater_than_0)

# %%
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G_greater_than_0)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G_greater_than_0, pos, partition.keys(), node_size=300,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G_greater_than_0, pos, alpha=0.5)
nx.draw_networkx_labels(G_greater_than_0, pos, font_size=12)
plt.show()

# %%
groups = {num:[] for num in partition.values()}
for k, v in partition.items():
    groups[v].append(codes.loc[k]['Name'])

# %%
print(groups[0])
# Out:
# ['Albania', 'Germany', 'Burundi', "C̫te d'Ivoire", 'Mexico', 'Japan', 'Canada', 'Guyana', 'Mozambique', 'Switzerland', 'Iceland', 'Poland']

# %%
print(groups[1])
# Out:
# ['Armenia', 'India', 'Liberia', 'Kuwait', 'Hong Kong', 'Pakistan', 'Oman', 'Nicaragua', 'Slovenia', 'Senegal', 'Malta', 'El Salvador']

# %%
print(groups[2])
# Out:
# ['American Samoa', 'Czech Republic', 'Georgia', 'Bermuda', 'Ghana', 'Korea, Republic of', 'Brunei Darussalam', 'Madagascar', 'Belize', 'Cayman Islands', 'Finland', 'Ireland', 'Venezuela, Bolivarian Republic of', 'Moldova, Republic of', 'Viet Nam']

# %%
print(groups[3])
# Out:
# ['Aruba', 'Cambodia', 'Zimbabwe', 'Belgium', 'Haiti', 'Jordan', 'Trinidad and Tobago', 'Chile', 'Northern Mariana Islands', 'Uganda', 'Ecuador', 'Luxembourg', 'Norway', 'Saint Vincent and the Grenadines']

# %%
print(groups[4])
# Out:
# ['Azerbaijan', 'Estonia', 'Virgin Islands, U.S.', 'Papua New Guinea', 'Gabon', 'Bhutan', 'Croatia', 'Mongolia', 'Botswana', 'Denmark', 'Paraguay', 'Spain', 'Saint Lucia', 'Panama', 'Lithuania', 'Nigeria', 'Qatar']

# %%
print(groups[5])
# Out:
# ['Bosnia and Herzegovina', 'Barbados', 'Turkey', 'Costa Rica', 'Egypt', 'Macedonia, the Former Yugoslav Republic of', 'Macao', 'Algeria', 'Slovakia', 'Saudi Arabia']

# %%
print(groups[6])
# Out:
# ['Bangladesh', 'Montenegro']

# %%
print(groups[7])
# Out:
# ['Burkina Faso', 'Brazil', 'Tanzania, United Republic of', 'Cameroon', 'Morocco', 'Dominican Republic', 'Comoros', 'Tunisia', 'Greece', 'Israel', 'Sri Lanka', 'Thailand']

# %%
print(groups[8])
# Out:
# ['Bulgaria', 'Fiji', 'French Polynesia', 'China', 'Guam', 'Gambia', 'Mauritania', 'Jamaica', 'South Africa', 'Singapore']

# %%
print(groups[9])
# Out:
# ['Bolivia, Plurinational State of', 'Hungary', 'Lebanon', 'Mauritius', 'Honduras', "Lao People's Democratic Republic", 'Italy', 'New Caledonia', 'Suriname', 'United States', 'Sweden', 'Netherlands', 'Yemen']

# %%
G = nx.karate_club_graph()

# compute the best partition
partition = louvain_community.best_partition(G)

# draw the graph
pos = nx.spring_layout(G)
# color the nodes according to their partition
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40,
                       cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()

# %%
print(df[(df['j'] == 'ME') & (df['i'] == 'BD')])
# Out:
#        i   j      D_ij  civ_i civ_j civ_ij  comciv
# 1753  BD  ME  3.302314  islam   NaN    NaN       0

# %%
df[df['i'] == 'ME']
# Out:
#        i   j       D_ij civ_i  civ_j civ_ij  comciv
# 8956  ME  MG -11.240130   NaN  afric    NaN       0
# 8957  ME  MK   0.028293   NaN  ortho    NaN       0
# 8958  ME  ML  -4.693233   NaN  islam    NaN       0
# 8959  ME  MN  -2.744400   NaN  buddh    NaN       0
# 8960  ME  MO  -0.728353   NaN    NaN    NaN       0
# 8961  ME  MP -11.240130   NaN    NaN    NaN       0
# 8962  ME  MR  -4.304880   NaN  afric    NaN       0
# 8963  ME  MT -11.240130   NaN  wstrn    NaN       0
# 8964  ME  MU   0.241820   NaN  afric    NaN       0
# 8965  ME  MX  -3.485166   NaN  latam    NaN       0
# 8966  ME  MY  -1.123071   NaN  islam    NaN       0
# 8967  ME  MZ   0.526660   NaN  afric    NaN       0
# 8968  ME  NC -11.240130   NaN    NaN    NaN       0
# 8969  ME  NG  -1.707067   NaN  afric    NaN       0
# 8970  ME  NI -11.240130   NaN  latam    NaN       0
# 8971  ME  NL  -4.055568   NaN  wstrn    NaN       0
# 8972  ME  NO   1.314440   NaN  wstrn    NaN       0
# 8973  ME  NP   2.491122   NaN  hindu    NaN       0
# 8974  ME  NZ  -4.770020   NaN  wstrn    NaN       0
# 8975  ME  OM  -0.332904   NaN  islam    NaN       0
# 8976  ME  PA  -0.193788   NaN  latam    NaN       0
# 8977  ME  PE  -3.979727   NaN  latam    NaN       0
# 8978  ME  PF -11.240130   NaN    NaN    NaN       0
# 8979  ME  PG  -0.041185   NaN  wstrn    NaN       0
# 8980  ME  PH  -4.121898   NaN  wstrn    NaN       0
# 8981  ME  PK  -3.400206   NaN  islam    NaN       0
# 8982  ME  PL  -3.592995   NaN  wstrn    NaN       0
# 8983  ME  PT -11.240130   NaN  wstrn    NaN       0
# 8984  ME  PY   0.673876   NaN  latam    NaN       0
# 8985  ME  QA -11.240130   NaN  islam    NaN       0
# 8986  ME  RU -11.240130   NaN  ortho    NaN       0
# 8987  ME  SA  -2.456063   NaN  islam    NaN       0
# 8988  ME  SD -11.240130   NaN  islam    NaN       0
# 8989  ME  SE -11.240130   NaN  wstrn    NaN       0
# 8990  ME  SG  -4.107236   NaN  buddh    NaN       0
# 8991  ME  SI  -2.565873   NaN  wstrn    NaN       0
# 8992  ME  SK  -1.495842   NaN  wstrn    NaN       0
# 8993  ME  SN   0.139675   NaN  islam    NaN       0
# 8994  ME  SR  -2.696790   NaN    NaN    NaN       0
# 8995  ME  SV  -4.543901   NaN  latam    NaN       0
# 8996  ME  TH  -4.548577   NaN  buddh    NaN       0
# 8997  ME  TN  -1.926832   NaN  islam    NaN       0
# 8998  ME  TR -11.240130   NaN  islam    NaN       0
# 8999  ME  TT -11.240130   NaN  wstrn    NaN       0
# 9000  ME  TZ   1.266909   NaN  afric    NaN       0
# 9001  ME  UA   1.169300   NaN  ortho    NaN       0
# 9002  ME  UG  -2.042170   NaN  afric    NaN       0
# 9003  ME  US -11.240130   NaN  wstrn    NaN       0
# 9004  ME  UY  -5.151601   NaN  latam    NaN       0
# 9005  ME  UZ -11.240130   NaN  islam    NaN       0
# 9006  ME  VC -11.240130   NaN  latam    NaN       0
# 9007  ME  VE -11.240130   NaN  latam    NaN       0
# 9008  ME  VI  -3.890640   NaN    NaN    NaN       0
# 9009  ME  VN  -1.249032   NaN  sinic    NaN       0
# 9010  ME  YE   0.582180   NaN  islam    NaN       0
# 9011  ME  ZA  -1.785433   NaN  afric    NaN       0
# 9012  ME  ZM  -3.719981   NaN  afric    NaN       0
# 9013  ME  ZW  -1.373493   NaN  afric    NaN       0
